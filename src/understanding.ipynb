# %%
import pandas as pd

df = pd.read_csv('../database/database.csv')

# %%
df['Histórico/Complemento'].unique()
# Out:
# array(['SALDO DIA', 'PIX RECEBIDO', 'PIX ENVIADO', 'CREDITO JUROS',
#        'CORRECAO MONETARIA', 'PAG ORGAOS GOV IBC', 'PAG BOLETO IBC',
#        'DEP DINHEIRO CORBAN', 'DEPOSITO DINH LOTERIC',
#        'Histórico/Complemento'], dtype=object)
